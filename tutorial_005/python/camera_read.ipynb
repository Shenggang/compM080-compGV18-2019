# %% [markdown]
# ## variables
#
# points, edges, faces, efaces, fvertices
#
#
#
#
#
#
#
#
#
#
#
#
#
#  facelist, edgelist, edgeface-list and facevertex-list

# %% [markdown]
# ![Screenshot%20%283%29.png](attachment:Screenshot%20%283%29.png)

# %% [markdown]
# # Explanination on Images

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Obama
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # NMF
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Recomendation
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data is only unique in higher dimensions

# %% [markdown]
# # HERE
# ![Screenshot%20%281%29.png](attachment:Screenshot%20%281%29.png)
#
#
# ![Screenshot.png](attachment:Screenshot.png)

# %% [markdown]
# # Laplacian smoothing
#
#
# ![Screenshot%20%282%29.png](attachment:Screenshot%20%282%29.png)
